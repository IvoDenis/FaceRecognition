# %%
import pandas as pd

# %%
df_1=pd.read_csv('Cards')
df_2=pd.read_csv('Tests')
print(df_1)
# Out:
#    Unnamed: 0         filename  result
# 0           0  card/found1.png    True
# 1           1  card/found2.png    True
# 2           2  card/found3.png    True
# 3           3  card/found4.png    True
# 4           4  card/found5.png    True
# 5           5  card/found6.png    True
# 6           6  card/found7.png    True
# 7           7  card/found8.png    True
# 8           8  card/found9.png    True

# %%
print(df_2)
# Out:
#     Unnamed: 0     filename  result
# 0            0   test/1.jpg     1.0
# 1            1  test/10.jpg     1.0
# 2            2  test/11.jpg     1.0
# 3            3   test/2.jpg     1.0
# 4            4   test/3.jpg     1.0
# 5            5   test/4.jpg     1.0
# 6            6   test/5.jpg     1.0
# 7            7   test/6.jpg     1.0
# 8            8   test/7.jpg     1.0
# 9            9   test/8.jpg     1.0
# 10          10   test/9.jpg     1.0

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.figure(figsize=(24,12))
plt.rc('axes', labelsize=20)
plt.rc('axes',titlesize=20)
plt.rc('legend', fontsize=20)
plt.title("График истинности") # заголовок
plt.xlabel("X, пиксель") # ось абсцисс
plt.ylabel("Y, пиксель") # ось ординат
plt.grid()      # включение отображение сетки
plt.plot(df_1['Unnamed: 0'], df_1['result'],'r',label="Результат")  # построение графика
plt.legend(loc=0)
plt.savefig('График истинности')

# %%
data=df_1[['filename','result']]
print(data)
# Out:
#           filename  result
# 0  card/found1.png    True
# 1  card/found2.png    True
# 2  card/found3.png    True
# 3  card/found4.png    True
# 4  card/found5.png    True
# 5  card/found6.png    True
# 6  card/found7.png    True
# 7  card/found8.png    True
# 8  card/found9.png    True

# %%
plt.figure(figsize=(24,8))
plt.rc('axes', labelsize=30)
plt.rc('axes',titlesize=30)
plt.rc('legend', fontsize=30)
plt.xlabel("Текущий файл") # ось абсцисс
plt.ylabel("predicted(true)/real") # ось ординат
plt.title("Гистограмма правильности распознания лиц")
plt.bar(df_1['filename'],df_1['result'])
plt.show()

# %%
plt.figure(figsize=(24,8))
plt.rc('axes', labelsize=30)
plt.rc('axes',titlesize=30)
plt.rc('legend', fontsize=30)
plt.xlabel("Текущий файл") # ось абсцисс
plt.ylabel("predicted(true)/real") # ось ординат
plt.title("Гистограмма правильности распознания лиц")
plt.bar(df_2['filename'],df_2['result'])
plt.show()
